# %%
sc

# %%
! pssh -h ../../ip.list -i ls -alh /data/tmp
# Out:
# [1] 20:20:31 [SUCCESS] 172.31.21.210
# total 7.6G
# drwxr-xr-x 2 ubuntu ubuntu 4.0K Oct 15 20:19 .
# drwxr-xr-x 6 root   root   4.0K Oct 15 19:34 ..
# -rw-rw-r-- 1 ubuntu ubuntu 639M Jun 10 20:47 pr_day_BCSD_historical_r1i1p1_ACCESS1-0_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 664M Jun 11 17:33 pr_day_BCSD_historical_r1i1p1_CSIRO-Mk3-6-0_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 635M Jun 10 21:37 pr_day_BCSD_historical_r1i1p1_inmcm4_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 759M Jun 11 04:03 pr_day_BCSD_historical_r1i1p1_MIROC-ESM-CHEM_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 672M Jun 11 10:18 pr_day_BCSD_historical_r1i1p1_MPI-ESM-LR_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 740M Jun 11 05:04 tasmax_day_BCSD_historical_r1i1p1_CanESM2_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 252M Oct 15 20:19 tasmax_day_BCSD_historical_r1i1p1_MIROC5_1997.nc
# -rw-rw-r-- 1 ubuntu ubuntu 757M Jun 11 08:22 tasmax_day_BCSD_historical_r1i1p1_MIROC5_1997.nc.1
# ...

# %%
def get_files(path):
    import os
    return os.listdir(path)
